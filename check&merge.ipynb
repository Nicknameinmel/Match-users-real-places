# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 读取数据_1
df_ad = pd.read_csv(r'C:\Users\cc\Documents\经纬度地址匹配\Clients_address.csv')
df_ad.head()
# 居住省份，居住城市，居住县区，居住地址 or 居住地址.1
# user_id
# 授信成功（保留）
# Out:
#   居住省份  居住城市 居住县区           居住地址 单位省份  单位城市 单位县区  \
# 0  贵州省   毕节市  黔西县           迎宾小区  贵州省   毕节市  黔西县
# 1  河南省  平顶山市  卫东区  平顶山市第一人民医院家属院  河南省  平顶山市  卫东区
# 2  云南省   曲靖市  会泽县           园丁小区  云南省   曲靖市  会泽县
# 3  辽宁省   沈阳市  法库县           剑桥世家  辽宁省   沈阳市  法库县
# 4  吉林省   吉林市  昌邑区          中海岳江府  吉林省   吉林市  龙潭区
#
#                             单位地址                                     公司地址  \
# 0                           水西大厦                            贵州省毕节市黔西县水西大厦
# 1  河南省平顶山市卫东区优越路117号靠近平顶山市第一人民医院  河南省平顶山市卫东区河南省平顶山市卫东区优越路117号靠近平顶山市第一人民医院
# 2                           会泽三中                            云南省曲靖市会泽县会泽三中
# 3                        法库县四家子乡                         辽宁省沈阳市法库县法库县四家子乡
# 4                          江北派出所                           吉林省吉林市龙潭区江北派出所
#
#                     居住地址.1                      user_id(md5)  是否授信成功,1:是；0:否  \
# 0            贵州省毕节市黔西县迎宾小区  16c91e075d2107f3f52de5a71e5543b5               1
# ...

# %%
# 读取数据_2
df_loc = pd.read_csv(r'C:\Users\cc\Documents\经纬度地址匹配\Clients_lon&lat.csv')
df_loc.head()
# b.location_lat,b.location_lng,b.devicetype(OFFLINE_PAD 是中介)
# user_id
# 授信成功（保留）
# Out:
#        a.credit_apply_id     a.apply_start_time a.product_no     a.product_id  \
# 0  000CA2021060000018415  2021-06-23 15:52:38.0   PN00000001  PN00000001-0009
# 1  000CA2021060000018415  2021-06-23 15:52:38.0   PN00000001  PN00000001-0009
# 2  000CA2021060000018415  2021-06-23 15:52:38.0   PN00000001  PN00000001-0009
# 3  000CA2021060000018415  2021-06-23 15:52:38.0   PN00000001  PN00000001-0009
# 4  000CA2021060000018415  2021-06-23 15:52:38.0   PN00000001  PN00000001-0009
#
#    a.rn                      user_id(md5)     b.devicetype b.devicebrand  \
# 0     1  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID         HONOR
# 1     1  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID         HONOR
# 2     1  a77b3cc1d5428f92c52b648f903258de      OFFLINE_PAD        XIAOMI
# 3     1  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID         HONOR
# 4     1  a77b3cc1d5428f92c52b648f903258de      OFFLINE_PAD        XIAOMI
#
# ...

# %%
df_ad.count()
# Out:
# 居住省份              400
# 居住城市              400
# 居住县区              399
# 居住地址              400
# 单位省份              400
# 单位城市              400
# 单位县区              398
# 单位地址              400
# 公司地址              400
# 居住地址.1            400
# user_id(md5)      400
# 是否授信成功,1:是；0:否    400
# Unnamed: 12         0
# Unnamed: 13         0
# Unnamed: 14         0
# Unnamed: 15         0
# Unnamed: 16         0
# Unnamed: 17         0
# Unnamed: 18         0
# Unnamed: 19         0
# dtype: int64

# %%
df_loc.count()
# Out:
# a.credit_apply_id     6243
# a.apply_start_time    6243
# a.product_no          6243
# a.product_id          6243
# a.rn                  6243
# user_id(md5)          6243
# b.devicetype          6237
# b.devicebrand         6237
# b.location_lat        5770
# b.location_lng        5770
# b.dt                  6243
# b.createtime          6243
# 是否授信成功,1:是；0:否        6243
# dtype: int64

# %%
#看是否有空值
np.any(df_loc.isnull())
# Out:
# True

# %%
df_loc.info()
df_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6243 entries, 0 to 6242
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   a.credit_apply_id   6243 non-null   object
#  1   a.apply_start_time  6243 non-null   object
#  2   a.product_no        6243 non-null   object
#  3   a.product_id        6243 non-null   object
#  4   a.rn                6243 non-null   int64
#  5   user_id(md5)        6243 non-null   object
#  6   b.devicetype        6237 non-null   object
#  7   b.devicebrand       6237 non-null   object
#  8   b.location_lat      5770 non-null   float64
#  9   b.location_lng      5770 non-null   float64
#  10  b.dt                6243 non-null   object
#  11  b.createtime        6243 non-null   object
#  12  是否授信成功,1:是；0:否      6243 non-null   int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 634.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df_loc.isnull().sum()/len(df_loc)
# Out:
# a.credit_apply_id     0.000000
# a.apply_start_time    0.000000
# a.product_no          0.000000
# a.product_id          0.000000
# a.rn                  0.000000
# user_id(md5)          0.000000
# b.devicetype          0.000961
# b.devicebrand         0.000961
# b.location_lat        0.075765
# b.location_lng        0.075765
# b.dt                  0.000000
# b.createtime          0.000000
# 是否授信成功,1:是；0:否        0.000000
# dtype: float64

# %%
df_ad = df_ad.drop([
'单位省份',           
'单位城市',              
'单位县区',              
'单位地址',             
'公司地址',            
'Unnamed: 12',         
'Unnamed: 13',         
'Unnamed: 14',         
'Unnamed: 15',         
'Unnamed: 16',         
'Unnamed: 17',         
'Unnamed: 18',        
'Unnamed: 19',      
                ],axis=1)

df_loc = df_loc.drop([
'a.apply_start_time',
'a.credit_apply_id',   
'a.product_no',        
'a.product_id',         
'a.rn',
'b.devicebrand',
'b.dt',                 
'b.createtime',               
                ],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-8238f0abd992> in <module>
# ----> 1 df_ad = df_ad.drop([
#       2 '单位省份',
#       3 '单位城市',
#       4 '单位县区',
#       5 '单位地址',
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_loc.head()
df_ad.head()
# Out:
#   居住省份  居住城市 居住县区           居住地址                   居住地址.1  \
# 0  贵州省   毕节市  黔西县           迎宾小区            贵州省毕节市黔西县迎宾小区
# 1  河南省  平顶山市  卫东区  平顶山市第一人民医院家属院  河南省平顶山市卫东区平顶山市第一人民医院家属院
# 2  云南省   曲靖市  会泽县           园丁小区            云南省曲靖市会泽县园丁小区
# 3  辽宁省   沈阳市  法库县           剑桥世家            辽宁省沈阳市法库县剑桥世家
# 4  吉林省   吉林市  昌邑区          中海岳江府           吉林省吉林市昌邑区中海岳江府
#
#                        user_id(md5)  是否授信成功,1:是；0:否
# 0  16c91e075d2107f3f52de5a71e5543b5               1
# 1  2b92f942b6de4bb460583506f3a112d2               1
# 2  1919c64dcd8e85d31abd7c232b26e1b9               1
# 3  0dcfdd9b23dca99a8ff4145b21dfaa37               1
# 4  660f73fe3be8fe34ff83bfbf1ed8d79b               1

# %%
df=pd.merge(df_loc,df_ad,on='user_id(md5)',how='left')
df.head()
# Out:
#       a.apply_start_time                      user_id(md5)     b.devicetype  \
# 0  2021-06-23 15:52:38.0  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID
# 1  2021-06-23 15:52:38.0  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID
# 2  2021-06-23 15:52:38.0  a77b3cc1d5428f92c52b648f903258de      OFFLINE_PAD
# 3  2021-06-23 15:52:38.0  a77b3cc1d5428f92c52b648f903258de  OFFLINE_ANDROID
# 4  2021-06-23 15:52:38.0  a77b3cc1d5428f92c52b648f903258de      OFFLINE_PAD
#
#    b.location_lat  b.location_lng  是否授信成功,1:是；0:否_x 居住省份 居住城市 居住县区 居住地址  \
# 0       27.127034      115.001836                 1  江西省  吉安市  吉州区  北门街
# 1       27.127044      115.002040                 1  江西省  吉安市  吉州区  北门街
# 2       27.132811      115.007894                 1  江西省  吉安市  吉州区  北门街
# 3       27.127124      115.001423                 1  江西省  吉安市  吉州区  北门街
# 4       27.132732      115.007517                 1  江西省  吉安市  吉州区  北门街
#
#          居住地址.1  是否授信成功,1:是；0:否_y
# 0  江西省吉安市吉州区北门街                 1
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# a.apply_start_time    0.000000
# user_id(md5)          0.000000
# b.devicetype          0.000961
# b.location_lat        0.075765
# b.location_lng        0.075765
# 是否授信成功,1:是；0:否_x      0.000000
# 居住省份                  0.000000
# 居住城市                  0.000000
# 居住县区                  0.000801
# 居住地址                  0.000000
# 居住地址.1                0.000000
# 是否授信成功,1:是；0:否_y      0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6243 entries, 0 to 6242
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   a.apply_start_time  6243 non-null   object
#  1   user_id(md5)        6243 non-null   object
#  2   b.devicetype        6237 non-null   object
#  3   b.location_lat      5770 non-null   float64
#  4   b.location_lng      5770 non-null   float64
#  5   是否授信成功,1:是；0:否_x    6243 non-null   int64
#  6   居住省份                6243 non-null   object
#  7   居住城市                6243 non-null   object
#  8   居住县区                6238 non-null   object
#  9   居住地址                6243 non-null   object
#  10  居住地址.1              6243 non-null   object
#  11  是否授信成功,1:是；0:否_y    6243 non-null   int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 634.1+ KB

# %%
df.to_csv(r'C:\Users\cc\Documents\经纬度地址匹配\data.csv',encoding = 'utf-8-sig')
